# %%
from src.GPC_parser import GPCCalibrationParser, construct_filename

# %% [markdown]
# Define Project Data

# %%
# Build filename 
Project_Info = {
    "Project": "A069",
    "Task": "T02",
    "Experiment": "E01",
    "Equipment": "GPC1",
    "Batch": "B01",
    "Repeat": "R01",
    "Method": "M01"
}

# %%
# Caller decides to tag calibration outputs:
fname = construct_filename(Project_Info, suffix="CLBRTN")
print(fname)
# A069_T02_E01_GPC1_B01_R01_M01_CLBRTN.csv

parser = GPCCalibrationParser()
df = parser.run("Data/QuickReport", fname)
# Out:
# A069_T02_E01_GPC1_B01_R01_M01_CLBRTN.csv
# Calibration data written to: c:\Users\hanfrey\Gits\GPC\A069_T02_E01_GPC1_B01_R01_M01_CLBRTN.csv
#     Exp. RT (min)       MW Mass     Peak Area Signal        Vial
# 0           9.589  6085000  0.4  1.268041e+05    RID    PS-H_Red
# 1          10.072  2811000  0.4  1.145956e+05    RID  PS-H_White
# 2          11.012   935000  0.4  1.386143e+05    RID   PS-H_Blue
# 3          11.633   474500  0.8  2.614364e+05    RID    PS-H_Red
# 4          11.827   365000  0.4  1.217043e+05    RID    PS-M_Red
# 5          12.416   182200  0.4  1.257711e+05    RID  PS-M_White
# 6          12.426   182200  0.8  2.387500e+05    RID  PS-H_White
# 7          13.058    87200  0.4  1.567740e+05    RID   PS-M_Blue
# 8          13.304    66600  0.8  2.793047e+05    RID   PS-H_Blue
# 9          13.536    50700  0.8  2.512723e+05    RID    PS-M_Red
# 10         14.089    26390  0.8  2.531559e+05    RID  PS-M_White
# ...
