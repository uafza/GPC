# %%
# --- imports & path setup ---
import sys
from pathlib import Path

SRC = Path("src").resolve()
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

# Core modules (no nested imports yet)
from parser.batch_parser import HPLCBatchParser
from parser.calibration_parser import GPCCalibrationParser
from parser.utils import construct_filename
from parser.run import run_workflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 13
#      11 from parser.calibration_parser import GPCCalibrationParser
#      12 from parser.utils import construct_filename
# ---> 13 from parser.run import run_workflow
#
# File ~\Gits\GPC\src\parser\run.py:3
#       1 # src/parser/run.py
#       2 from parser.workflow_gpc import run_gpc_workflow
# ----> 3 from parser.workflow_hplc import run_hplc_workflow
#       5 def run_workflow(Project_Info: dict, base_folder: str = ".", out_dir: str = "results"):
#       6     """
#       7     Decide which workflow to run (GPC or HPLC) based on Project_Info['Workflow'].
#       8     """
#
# File ~\Gits\GPC\src\parser\workflow_hplc.py:5
#       3 from pathlib import Path
#       4 import pandas as pd
# ----> 5 from batch_parser import HPLCBatchParser
# ...

# %% [markdown]
# Define Project Data

# %%
# Your project info
Project_Info = {
    "Project": "A069",
    "Task": "T02",
    "Experiment": "E01",
    "Equipment": "GPC1",
    "Batch": "B01",
    "Repeat": "R01",
    "Method": "M01",
    "Workflow": "GPC",
}

# Run it
run_workflow(Project_Info, base_folder=".", out_dir="results")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#       2 Project_Info = {
#       3     "Project": "A069",
#       4     "Task": "T02",
#    (...)     10     "Workflow": "GPC",
#      11 }
#      13 # Run it
# ---> 14 run_workflow(Project_Info, base_folder=".", out_dir="results")
#
# NameError: name 'run_workflow' is not defined
